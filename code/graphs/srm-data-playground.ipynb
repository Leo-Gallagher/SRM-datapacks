# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as mtick
import seaborn as sns
import scipy as sp
import textwrap

# %%
# define the root_path
root_path = r'/Users/leogallagher/Documents/FMA-Work/KRG/PFM/Code/Expenditure'
## Import raw data

df = pd.read_csv(root_path + r'/processed-data/srm-processed-data/230301-srm-data.csv')

# %% [markdown]
# ## df.describe(include='all')

# %%
numeric_columns = df.describe().columns
pd.plotting.scatter_matrix(df[numeric_columns], alpha=0.2, figsize = (15,10))
plt.show()
